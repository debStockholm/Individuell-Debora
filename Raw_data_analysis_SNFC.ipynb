# %% [markdown]
# # EDA   - SNCF

# %%
import pandas as pd
from pandasgui import show
from warnings import filterwarnings
filterwarnings("ignore")

# %%
data = pd.read_csv('SNCF_dataset_raw.csv', sep=';')
display(data.head(10))  
show(data)           # Opens an interactive GUI to explore the DataFrame including sorting, filtering, and visualization
# Out:
#       Date   Service       Gare de départ       Gare d'arrivée  \
# 0  2018-01  National     BORDEAUX ST JEAN   PARIS MONTPARNASSE
# 1  2018-01  National    LA ROCHELLE VILLE   PARIS MONTPARNASSE
# 2  2018-01  National   PARIS MONTPARNASSE              QUIMPER
# 3  2018-01  National   PARIS MONTPARNASSE              ST MALO
# 4  2018-01  National   PARIS MONTPARNASSE  ST PIERRE DES CORPS
# 5  2018-01  National              QUIMPER   PARIS MONTPARNASSE
# 6  2018-01  National               RENNES       LYON PART DIEU
# 7  2018-01  National  ST PIERRE DES CORPS   PARIS MONTPARNASSE
# 8  2018-01  National                TOURS   PARIS MONTPARNASSE
# 9  2018-01  National               NANTES           STRASBOURG
#
#    Durée moyenne du trajet  Nombre de circulations prévues  \
# 0                      141                             870
# 1                      165                             222
# 2                      220                             248
# ...
