# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandasgui import show

# %% [markdown]
# Import datafile for analysis

# %% [markdown]
# First: import data and check everything is in a decent format.
#
# In this case:
#
# imported dataset;
#
# delimited by semicolon;
#
# encoding: to understand french letters;
#
# on bad lines: "skip", skip wrong formatted lines, not really relevant in our dataset;
#
# engine: "python" tell which engine chosen to parse, not really necessary now
#
#
# #show(data)= this open a web window with all data in nice table format.
# Useful since I cant see the whole database preview on Jupyter

# %%
data = pd.read_csv(
     "SNCF_dataset.csv",   
    sep=';',                   # semikolon-separerad
    encoding='utf-8-sig',      # för franska tecken så det inte blir konstigt
    #on_bad_lines='skip',       # hoppar över rader som är helt trasiga      
    #engine = 'python'          # för att hantera inbäddade semikolon
)


#show(data)                    #OBS pandasgui, öppnas separat
data.head(5)
# Out:
#       Date   Service      Gare de départ       Gare d'arrivée  \
# 0  2018-01  National    BORDEAUX ST JEAN   PARIS MONTPARNASSE
# 1  2018-01  National   LA ROCHELLE VILLE   PARIS MONTPARNASSE
# 2  2018-01  National  PARIS MONTPARNASSE              QUIMPER
# 3  2018-01  National  PARIS MONTPARNASSE              ST MALO
# 4  2018-01  National  PARIS MONTPARNASSE  ST PIERRE DES CORPS
#
#    Durée moyenne du trajet  Nombre de circulations prévues  \
# 0                      141                             870
# 1                      165                             222
# 2                      220                             248
# 3                      156                             102
# 4                       61                             391
#
#    Nombre de trains annulés  Commentaire annulations  \
# 0                         5                      NaN
# 1                         0                      NaN
# 2                         1                      NaN
# ...

# %% [markdown]
# Sort my database:
# 1. only National service and Delays cause by rollings stocks/infrastructure in 2023
#
#
# "Un train est considéré à l'heure si son retard au terminus est inférieur à 5min pour un parcours inférieur à 1h30
#
# Un train est considéré à l'heure si son retard au terminus est inférieur à 10min pour un parcours entre 1h30 et 3h
#
# Un train est considéré à l'heure si son retard au terminus est inférieur à 15min pour un parcours au-delà de 3h"

# %%
national_data = data[(data['Service'] == 'National') & (data['Date'].str.startswith('2023'))]       #choose only National trains ad year=2023
columns_to_drop = [       'Service',                                #working on delays caused by infrastructure/rolling stocks, drop everything else
                   'Commentaire annulations', 
                   'Commentaire retards au départ', 
                   'Commentaire retards à l\'arrivée',
                   'Nombre de trains en retard au départ',
                   'Nombre de trains en retard à l\'arrivée',
                   'Retard moyen trains en retard > 15 (si liaison concurrencée par vol)',
                   'Retard moyen des trains en retard au départ',
                   'Retard moyen de tous les trains au départ',
                   'Retard moyen de tous les trains à l\'arrivée',
                   'Retard moyen des trains en retard à l\'arrivée',
                   'Prct retard pour causes externes',
                   'Prct retard pour cause gestion trafic',
                   'Prct retard pour cause gestion en gare et réutilisation de matériel',
                   'Prct retard pour cause prise en compte voyageurs (affluence, gestions PSH, correspondances)',
          ]

   #get only to decimals in the last two columns

nationaltrains_data_1 = national_data.drop(columns=columns_to_drop).copy()
columns_to_format = [
    'Prct retard pour cause infrastructure',
    'Prct retard pour cause matériel roulant'
]
nationaltrains_data_1[columns_to_format] = nationaltrains_data_1[columns_to_format].round(2)

#print(nationaltrains_data_1.columns)

display(nationaltrains_data_1.head(10))    #use display instead of print to get a nice table view!
# Out:
#          Date             Gare de départ       Gare d'arrivée  \
# 7430  2023-01           BORDEAUX ST JEAN   PARIS MONTPARNASSE
# 7431  2023-01  CHAMBERY CHALLES LES EAUX           PARIS LYON
# 7432  2023-01                MACON LOCHE           PARIS LYON
# 7433  2023-01                       METZ            PARIS EST
# 7434  2023-01                MONTPELLIER           PARIS LYON
# 7435  2023-01                  PARIS EST                 METZ
# 7436  2023-01                 PARIS LYON  AIX EN PROVENCE TGV
# 7437  2023-01                 PARIS LYON               ANNECY
# 7438  2023-01                 PARIS LYON           NICE VILLE
# 7439  2023-01         PARIS MONTPARNASSE            ANGOULEME
#
#       Durée moyenne du trajet  Nombre de circulations prévues  \
# 7430                      140                            1075
# 7431                      180                             334
# 7432                       99                             252
# ...

# %% [markdown]
# Saved view as new dataset: Delays in 2023 cause by Infrastructure / rolling stocks

# %%
nationaltrains_data_1.to_csv("Delays_Infr_RStocks_2023.csv", index=False, sep=';')
