# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandasgui
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ## Import dataset

# %%
data=pd.read_csv("Dataset_national_trains.csv", sep=";")

display(data.head(10))
# Out:
#    year month        date   service            depart_st           arrival_st  \
# 0  2018   Jan  2018-01-01  National     BORDEAUX ST JEAN   PARIS MONTPARNASSE
# 1  2018   Jan  2018-01-01  National    LA ROCHELLE VILLE   PARIS MONTPARNASSE
# 2  2018   Jan  2018-01-01  National   PARIS MONTPARNASSE              QUIMPER
# 3  2018   Jan  2018-01-01  National   PARIS MONTPARNASSE              ST MALO
# 4  2018   Jan  2018-01-01  National   PARIS MONTPARNASSE  ST PIERRE DES CORPS
# 5  2018   Jan  2018-01-01  National              QUIMPER   PARIS MONTPARNASSE
# 6  2018   Jan  2018-01-01  National               RENNES       LYON PART DIEU
# 7  2018   Jan  2018-01-01  National  ST PIERRE DES CORPS   PARIS MONTPARNASSE
# 8  2018   Jan  2018-01-01  National                TOURS   PARIS MONTPARNASSE
# 9  2018   Jan  2018-01-01  National               NANTES           STRASBOURG
#
#    avg_duration  exp_monthly_trains  cancelled_nb  delay>15  delay>30  \
# 0           141                 870             5       110        44
# 1           165                 222             0        22         5
# 2           220                 248             1        26        17
# 3           156                 102             0         8         6
# 4            61                 391             2        17         6
# 5           223                 256             1        21         9
# 6           233                  99             0         6         2
# 7            61                 410             1        26         9
# 8            75                 194             0         7         1
# 9           303                  39             0         5         2
#
#    delay>60  delay_external  delay_infrastructure  delay_traffic_management  \
# 0         8           36.13                 31.09                     10.92
# 1         0           15.38                 30.77                     38.46
# 2         7           26.92                 38.46                     15.38
# 3         4           23.08                 46.15                      7.69
# 4         0           21.21                 42.42                      9.09
# 5         2           27.78                 55.56                      0.00
# 6         1            0.00                 50.00                     25.00
# 7         0           22.73                 45.45                     16.67
# 8         0           25.00                 56.25                      6.25
# 9         1            0.00                  0.00                     33.33
#
#    delay_rolling_stock  delay_station_management  delay_passenger_related
# 0                15.97                      5.04                     0.84
# 1                11.54                      3.85                     0.00
# 2                19.23                      0.00                     0.00
# 3                15.38                      7.69                     0.00
# 4                21.21                      6.06                     0.00
# 5                 5.56                      5.56                     5.56
# 6                25.00                      0.00                     0.00
# 7                12.12                      1.52                     1.52
# 8                12.50                      0.00                     0.00
# 9                33.33                      0.00                    33.33

# %% [markdown]
# ##  Sorting

# %%
national_data = data[(data['year'] == 2023) & (data['service'] == 'National')]  # filter for year 2023

display(national_data.tail(5))    #use display instead of print to get a nice table view!"""
# Out:
#       year month        date   service           depart_st  \
# 8869  2023   Dec  2023-12-01  National  PARIS MONTPARNASSE
# 8870  2023   Dec  2023-12-01  National  PARIS MONTPARNASSE
# 8871  2023   Dec  2023-12-01  National          PARIS NORD
# 8872  2023   Dec  2023-12-01  National          STRASBOURG
# 8873  2023   Dec  2023-12-01  National               TOURS
#
#               arrival_st  avg_duration  exp_monthly_trains  cancelled_nb  \
# 8869               BREST           230                 276             2
# 8870   TOULOUSE MATABIAU           264                 219             4
# 8871               DOUAI            71                 136             0
# 8872              NANTES           337                  61             0
# 8873  PARIS MONTPARNASSE            74                 188             3
#
#       delay>15  delay>30  delay>60  delay_external  delay_infrastructure  \
# 8869        29         9         3           37.93                  3.45
# 8870        43        28        10           46.51                  9.30
# 8871        11         2         1           10.53                  5.26
# 8872         9         6         1           25.00                 12.50
# 8873         4         2         1           13.33                 26.67
#
#       delay_traffic_management  delay_rolling_stock  delay_station_management  \
# 8869                     10.34                20.69                     17.24
# 8870                     13.95                11.63                      4.65
# 8871                     15.79                47.37                     15.79
# 8872                      0.00                37.50                     25.00
# 8873                     40.00                13.33                      0.00
#
#       delay_passenger_related
# 8869                    10.34
# 8870                    13.95
# 8871                     5.26
# 8872                     0.00
# 8873                     6.67
